# %%
import pandas as pd

df = pd.read_csv("datasets/olist_products_dataset.csv")

df
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %% [markdown]
# Há dados faltantes neste dadaset?

# %%
df.isnull().any().any()
# Out:
# True

# %% [markdown]
# Quantos dados faltantes temos no dataset?

# %%
df.isnull().sum().sum()
# Out:
# 2448

# %% [markdown]
# Retirar os dados faltantes

# %%
df = df.dropna()

# %%
categorias = df['product_category_name']
categorias
# Out:
# 0                               perfumaria
# 1                                    artes
# 2                            esporte_lazer
# 3                                    bebes
# 4                    utilidades_domesticas
#                        ...
# 32946                     moveis_decoracao
# 32947    construcao_ferramentas_iluminacao
# 32948                      cama_mesa_banho
# 32949               informatica_acessorios
# 32950                      cama_mesa_banho
# Name: product_category_name, Length: 32340, dtype: object

# %% [markdown]
# Temos 32951 dados no dataset em diversas caterigorias que podem ser as mesmas ou nao

# %%
#  Qual é a categoria que mais vende?
categorias.describe()
# Out:
# count               32340
# unique                 73
# top       cama_mesa_banho
# freq                 3029
# Name: product_category_name, dtype: object

# %%
categorias.value_counts()
# Out:
# product_category_name
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: count, Length: 73, dtype: int64

# %%
df['volume_produto'] = df['product_length_cm'] * df['product_height_cm'] * df['product_width_cm']
# Out:
# C:\Users\Drac3\AppData\Local\Temp\ipykernel_14608\3362806198.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['volume_produto'] = df['product_length_cm'] * df['product_height_cm'] * df['product_width_cm']

# %%
df
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
#maiores produtos

df_sorted = df.sort_values(by='volume_produto', ascending=False)
df_sorted.head(50)
# Out:
#                              product_id  \
# 12802  256a9c364b75753b97bee410c9491ad8
# 25524  c1e0531cb1864fd3a0cae57dca55ca80
# 17303  3eb14e65e4208c6d94b7a32e41add538
# 10697  0b48eade13cfad433122f23739a66898
# 12146  f227e2d44f10f7dad30fb4dfa839e7a2
# 32532  90c1b4e040d1d1c45897ec2dad4a809d
# 16728  99ff40856c47a638df807c0a144470cc
# 3770   c6fdec160d0f8f488d9041316c85051d
# 7234   8d6f2c3454002d3f5aa7479a7fad7794
# 28145  0e9dfb804bafa3d68ef3ee7a621abfb2
# 27266  ab495f166205a883ffe5ab0b5b55f867
# 20574  a3cd9517ebf5a50dca25acce54f3b171
# 23988  ab50aa8d9af0addb7f96149c8b8cee86
# 1159   f97ad9066c718a6cef93dfcf253d3e0d
# 25978  f18f40e6344e72cfd537f21d9745e8cc
# 24685  c8d4b2652543be14a917376a17f426c2
# 30958  04abe952a7292c9914a0ddade6371114
# 9356   671be61e4013fc77e2d3586ffc1e51f1
# 17314  2a511952313989fa097fb038cd758dc5
# 23942  f3f12eabcd090650146791b249f48880
# 6212   e0c47a145f4748e4d7a418502d65aa35
# 13987  d13816a79f03bf978283d80fbeae06f8
# ...

# %%
df['volume_produto'].sort_values(ascending=False)
# Out:
# 12802    296208.0
# 25524    294000.0
# 17303    294000.0
# 10697    294000.0
# 12146    294000.0
#            ...
# 4415        352.0
# 20028       352.0
# 20041       352.0
# 961         288.0
# 32950       168.0
# Name: volume_produto, Length: 32340, dtype: float64

# %%
#produtos mais pesados
df_sorted = df.sort_values(by='product_weight_g', ascending=False)
df_sorted.head(50)
# Out:
#                              product_id  \
# 25166  26644690fde745fc4654719c3904e1db
# 24268  cb26d15d1b6eabaac7c0803774245884
# 1701   1c57458e824ca3d974ec1831a1a55e72
# 27266  ab495f166205a883ffe5ab0b5b55f867
# 19619  cdb8d3c880b6639a70764c6734e6bb69
# 1714   c04e948c6900ce99ac47d89b3b6d70cd
# 9363   8f73613d06e3a557da0249015cbae6b6
# 12376  773d43a287d64831b05013a73a33f229
# 32262  ebf1c13032246ea801765e8cb5417365
# 27230  e5f2d52b802189ee658865ca93d83a8f
# 9373   038e3a669bb495e56d9d609d874fb668
# 1738   0a859d8dc68f6a746b4709217110c439
# 19753  31d22f91c17551712034a105e70ab838
# 11327  8d4e92265a16e69a1e1d76e67e46d72f
# 7535   9dfef86fb34051388a7263a31642386c
# 19834  0f3777229e40207d248acfd6e1f716b6
# 8218   9fa7e05ae5cddeb74ff2fe5046b742db
# 8644   59f09deeea7c839a9212a19f3416b892
# 19875  9f82fdef2a36bb15d22d70af1aedb3ce
# 32179  d7f8b7443f6ae5796dabe493521a1e79
# 5465   df872c596e00cd0160e6c8eb5424739f
# 26912  bad9cd5ad615c0b5ba87448e03ec954c
# ...

# %%
df['product_weight_g'].sort_values(ascending=False)
# Out:
# 25166    40425.0
# 24268    30000.0
# 1701     30000.0
# 27266    30000.0
# 19619    30000.0
#           ...
# 15675        2.0
# 14997        0.0
# 9769         0.0
# 32079        0.0
# 13683        0.0
# Name: product_weight_g, Length: 32340, dtype: float64

# %%
df['product_name_lenght'].describe()
# Out:
# count    32340.000000
# mean        48.476592
# std         10.245699
# min          5.000000
# 25%         42.000000
# 50%         51.000000
# 75%         57.000000
# max         76.000000
# Name: product_name_lenght, dtype: float64

# %%
df['product_description_lenght'].describe()
# Out:
# count    32340.000000
# mean       771.492393
# std        635.124831
# min          4.000000
# 25%        339.000000
# 50%        595.000000
# 75%        972.000000
# max       3992.000000
# Name: product_description_lenght, dtype: float64

# %%
max_product_description_lenght = df['product_description_lenght'].max()
df_product_description_lenght = df.loc[df['product_description_lenght'] == max_product_description_lenght]
df_product_description_lenght
# Out:
#                              product_id product_category_name  \
# 31404  47d52bb24ef8a3aa09724f00604be3ba          dvds_blu_ray
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 31404                 30.0                      3992.0                 1.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 31404            2600.0               41.0               11.0
#
#        product_width_cm  volume_produto
# 31404              32.0         14432.0

# %%
df['product_photos_qty'].describe()
# Out:
# count    32340.000000
# mean         2.188961
# std          1.736787
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          3.000000
# max         20.000000
# Name: product_photos_qty, dtype: float64

# %%
max_photos_qty = df['product_photos_qty'].max()
df_max_photos = df.loc[df['product_photos_qty'] == max_photos_qty]
df_max_photos
# Out:
#                             product_id product_category_name  \
# 9022  f95d5d21561ea085ba1e1a4e53840844            brinquedos
#
#       product_name_lenght  product_description_lenght  product_photos_qty  \
# 9022                 62.0                       679.0                20.0
#
#       product_weight_g  product_length_cm  product_height_cm  \
# 9022            8900.0               32.0               49.0
#
#       product_width_cm  volume_produto
# 9022              34.0         53312.0

# %%
import pandas as pd

df_items = pd.read_csv("datasets/olist_order_items_dataset.csv")

df_items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df.isnull().any().any()
# Out:
# False

# %%
df_items['price'].describe()
# Out:
# count    112650.000000
# mean        120.653739
# std         183.633928
# min           0.850000
# 25%          39.900000
# 50%          74.990000
# 75%         134.900000
# max        6735.000000
# Name: price, dtype: float64

# %%
df_items_sorted_price_max = df_items.sort_values(by='price', ascending=False)
df_items_sorted_price_max.head(50)
# Out:
#                                 order_id  order_item_id  \
# 3556    0812eb902a67711a1cb742b3cdaa65ae              1
# 112233  fefacc66af859508bf1a7934eab1e97f              1
# 107841  f5136e38d1a14a4dbd87dff67da82701              1
# 74336   a96610ab360d42a2e5335a3998b4718a              1
# 11249   199af31afc78c699f0dbf71fb178d4d4              1
# 62086   8dbc85d1447242f3b127dda390d56e19              1
# 29193   426a9742b533fc6fed17d1fd6d143d7e              1
# 45843   68101694e5c5dc7330c91e1bbc36214f              1
# 78310   b239ca7cd485940b31882363b52e6674              1
# 59137   86c4eab1571921a6a6e248ed312f5a5a              1
# 56663   80dfedb6d17bf23539beeef3c768f4d7              1
# 67456   9a3966c23190dbdbaabed08e8429c006              1
# 28884   41b7766bb1df487d17fb9725b78ff509              1
# 69142   9de73f3e6157169ad6c32b9f313c7dcb              1
# 93516   d3f66901a6743e15f9311547cc623b91              1
# 102349  e85c92ee6a3ba1ef47e41c23286314d9              1
# ...

# %%
df_items_sorted_price_min = df_items.sort_values(by='price', ascending=True)
df_items_sorted_price_min.head(50)
# Out:
#                                 order_id  order_item_id  \
# 27652   3ee6513ae7ea23bdfab5b9ab60bffcb5              1
# 87081   c5bdd8ef3c0ec420232e668302179113              2
# 48625   6e864b3f0ec71031117ad4cf46b7f2a1              1
# 57297   8272b63d03f5f79c56e9e4120aec44ef              1
# 57302   8272b63d03f5f79c56e9e4120aec44ef              6
# 57303   8272b63d03f5f79c56e9e4120aec44ef              7
# 57304   8272b63d03f5f79c56e9e4120aec44ef              8
# 57305   8272b63d03f5f79c56e9e4120aec44ef              9
# 57306   8272b63d03f5f79c56e9e4120aec44ef             10
# 57307   8272b63d03f5f79c56e9e4120aec44ef             11
# 57308   8272b63d03f5f79c56e9e4120aec44ef             12
# 57309   8272b63d03f5f79c56e9e4120aec44ef             13
# 57310   8272b63d03f5f79c56e9e4120aec44ef             14
# 57316   8272b63d03f5f79c56e9e4120aec44ef             20
# 57315   8272b63d03f5f79c56e9e4120aec44ef             19
# 57311   8272b63d03f5f79c56e9e4120aec44ef             15
# ...

# %%
df_merged = pd.merge(df, df_items, on='product_id', how='inner')
df_merged
# Out:
#                               product_id   product_category_name  \
# 0       1e9e8ef04dbcff4541ed26657ea517e5              perfumaria
# 1       3aa071139cb16b67ca9e5dea641aaa2f                   artes
# 2       96bd76ec8810374ed1b65e291975717f           esporte_lazer
# 3       cef67bcfe19066a932b7673e239eb23d                   bebes
# 4       9dc1a7de274444849c219cff195d0b71   utilidades_domesticas
# ...                                  ...                     ...
# 111041  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 111042  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 111043  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 111044  83808703fc0706a22e264b9d75f04a2e  informatica_acessorios
# 111045  106392145fca363410d287a815be6de4         cama_mesa_banho
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                      40.0                       287.0                 1.0
# ...

# %%
df_merged.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count        111046.000000               111046.000000       111046.000000
# mean             48.775877                  787.866335            2.209706
# std              10.025570                  652.138503            1.721445
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  348.000000            1.000000
# 50%              52.000000                  603.000000            1.000000
# 75%              57.000000                  987.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count     111046.000000      111046.000000      111046.000000
# mean        2099.979657          30.211003          16.626362
# std         3754.785226          16.189352          13.467460
# ...

# %%
df_merged.value_counts()
# Out:
# product_id                        product_category_name              product_name_lenght  product_description_lenght  product_photos_qty  product_weight_g  product_length_cm  product_height_cm  product_width_cm  volume_produto  order_id                          order_item_id  seller_id                         shipping_limit_date  price   freight_value
# 00066f42aeeb9f3007548bb9d3f33c38  perfumaria                         53.0                 596.0                       6.0                 300.0             20.0               16.0               16.0              5120.0          f30149f4a8882a08895b6a242aa0d612  1              5670f4db5b62c43d542e1b2d56b0cf7c  2018-05-24 18:58:59  101.65  18.59            1
# ...

# %%
# quais os produtos mais caros?

df_merged_sorted_price_max = df_merged.sort_values(by='price', ascending=False)
df_merged_sorted_price_max.head(50)
# Out:
#                               product_id             product_category_name  \
# 20259   489ae2aa008f021502940f251d4cce7f             utilidades_domesticas
# 72948   69c590f7ffc7bf8db97190b6cb6ed62e                               pcs
# 48843   1bdf5e6731585cf01aa8169c7028d6ad                             artes
# 70869   a6492cc69376c469ab6f61d8f44de961                   eletroportateis
# 31828   c3ed642d592594bb648ff4a04cee2747                   eletroportateis
# 83459   259037a6a41845e455183f89c5035f18                               pcs
# 104910  a1beef8f3992dbd4cd8726796aa69c53             instrumentos_musicais
# 103370  6cdf8fc1d741c76586d8b6b15e9eef30                    consoles_games
# 45406   dd113cb02b2af9c8e5787e8f1f0722f6                     esporte_lazer
# 39462   6902c1962dd19d540807d0ab8fade5c6                relogios_presentes
# 22674   4ca7b91a31637bd24fb8e559d5e015e4                   eletroportateis
# ...

# %%
# quais os produtos mais baratos?

df_merged_sorted_price_min = df_merged.sort_values(by='price', ascending=True)
df_merged_sorted_price_min.head(50)
# Out:
#                               product_id              product_category_name  \
# 29221   8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
# 29223   8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
# 29222   8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
# 55170   05b515fdc76e888aada3c6d66c201dff                       beleza_saude
# 55171   05b515fdc76e888aada3c6d66c201dff                       beleza_saude
# 55172   05b515fdc76e888aada3c6d66c201dff                       beleza_saude
# 55173   05b515fdc76e888aada3c6d66c201dff                       beleza_saude
# 55174   05b515fdc76e888aada3c6d66c201dff                       beleza_saude
# 55175   05b515fdc76e888aada3c6d66c201dff                       beleza_saude
# 55176   05b515fdc76e888aada3c6d66c201dff                       beleza_saude
# 55177   05b515fdc76e888aada3c6d66c201dff                       beleza_saude
# ...

# %%
# quais os produtos com maior preço de frete?

df_merged_sorted_frete_max = df_merged.sort_values(by='freight_value', ascending=False)
df_merged_sorted_frete_max.head(50)
# Out:
#                               product_id  \
# 14080   ec31d2a17b299511e7c8627be9337b9b
# 69162   a3cd9517ebf5a50dca25acce54f3b171
# 69161   a3cd9517ebf5a50dca25acce54f3b171
# 42393   256a9c364b75753b97bee410c9491ad8
# 92849   97c948ebc8c04b26b7bbb095d4228f2a
# 92851   97c948ebc8c04b26b7bbb095d4228f2a
# 91588   46e24ce614899e36617e37ea1e4aa6ff
# 4718    363a9f5b97bf194da23858be722a7aa5
# 25234   7e53e051875b2a0c9f22acd8a9a29a20
# 4719    363a9f5b97bf194da23858be722a7aa5
# 99593   dc861f18267cce21f3b70f9f7990b8ce
# 79726   1d16c0509e7011656e03c6a582ff6667
# 101793  3a1855685a49813f60e6193864f7215e
# 73139   bc3c6d2a621414f2e1df7a8a32a2828e
# 73137   bc3c6d2a621414f2e1df7a8a32a2828e
# 73138   bc3c6d2a621414f2e1df7a8a32a2828e
# 73140   bc3c6d2a621414f2e1df7a8a32a2828e
# 73141   bc3c6d2a621414f2e1df7a8a32a2828e
# 73136   bc3c6d2a621414f2e1df7a8a32a2828e
# 37743   8d4e92265a16e69a1e1d76e67e46d72f
# 66305   24bf010d82955430eeea5ed7643711c7
# 39746   16c4e87b98a9370a9cbc3a4658a3f45b
# ...

# %%
# quais os produtos com menor preço de frete?

df_merged_sorted_frete_min = df_merged.sort_values(by='freight_value', ascending=True)
df_merged_sorted_frete_min.head(50)
# Out:
#                              product_id product_category_name  \
# 2343   53b36df67ebb7c41585e8d54d6772e08    relogios_presentes
# 47482  422879e10f46682990de24d770e7f83d    ferramentas_jardim
# 48939  7a10781637204d8d10485c71a6108a2e    relogios_presentes
# 2457   53b36df67ebb7c41585e8d54d6772e08    relogios_presentes
# 47468  422879e10f46682990de24d770e7f83d    ferramentas_jardim
# 2460   53b36df67ebb7c41585e8d54d6772e08    relogios_presentes
# 47467  422879e10f46682990de24d770e7f83d    ferramentas_jardim
# 47463  422879e10f46682990de24d770e7f83d    ferramentas_jardim
# 47462  422879e10f46682990de24d770e7f83d    ferramentas_jardim
# 47461  422879e10f46682990de24d770e7f83d    ferramentas_jardim
# 47460  422879e10f46682990de24d770e7f83d    ferramentas_jardim
# 47457  422879e10f46682990de24d770e7f83d    ferramentas_jardim
# 2461   53b36df67ebb7c41585e8d54d6772e08    relogios_presentes
# 2462   53b36df67ebb7c41585e8d54d6772e08    relogios_presentes
# ...

# %%
# volume x frete 
import matplotlib.pyplot as plt

# Supondo que df seja o seu DataFrame e que 'X' e 'Y' sejam os nomes das colunas que você quer plotar

# Criar um gráfico de dispersão
plt.figure(figsize=(10, 6)) # Define o tamanho da figura
plt.scatter(df_merged['volume_produto'], df_merged['freight_value']) # Cria um gráfico de dispersão com os dados

# Adicionar títulos e rótulos
plt.title('Gráfico de Dispersão entre X e Y')
plt.xlabel('X')
plt.ylabel('Y')

# Mostrar o gráfico
plt.show()

# %%
# peso x frete 
import matplotlib.pyplot as plt

# Supondo que df seja o seu DataFrame e que 'X' e 'Y' sejam os nomes das colunas que você quer plotar

# Criar um gráfico de dispersão
plt.figure(figsize=(10, 6)) # Define o tamanho da figura
plt.scatter(df_merged['product_weight_g'], df_merged['freight_value']) # Cria um gráfico de dispersão com os dados

# Adicionar títulos e rótulos
plt.title('Gráfico de Dispersão entre X e Y')
plt.xlabel('X')
plt.ylabel('Y')

# Mostrar o gráfico
plt.show()
